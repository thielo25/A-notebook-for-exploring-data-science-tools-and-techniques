# %% [markdown]
# Exercice 2 : Créer une cellule markdown avec le titre du notebook
#
# Créez une cellule markdown avec le titre Outils et écosystème de la science des données en utilisant un en-tête de style H1.

# %% [markdown]
# # Outils et écosystème de la science des données

# %% [markdown]
# Exercice 3 - Créer une cellule markdown pour une introduction
#
# Écrivez une phrase d’introduction sur le notebook comme suit :
#
# Dans ce notebook, les outils et l'écosystème de la science des données sont résumés.

# %% [markdown]
# Dans ce notebook, les outils et l'écosystème de la science des données sont résumés.

# %% [markdown]
# Exercice 10 - Insérer une cellule markdown pour lister les objectifs
#
# Sous la cellule d’introduction créée dans l’exercice 3, insérez une nouvelle cellule markdown pour lister les objectifs que ce notebook couvre (c’est-à-dire certains des points clés du cours). Dans cette nouvelle cellule, commencez par une ligne d’introduction intitulée : Objectifs : en gras. Ensuite, en utilisant une liste non ordonnée (puces), indiquez 3 à 5 éléments couverts dans ce notebook, tels que Lister les langages populaires pour la science des données.

# %% [markdown]
# **Objectif :**
# - Lister les langages populaires pour la science des données
# - Outils de la science des données
# - des bibliothèques couramment utilisées par les scientifiques des données

# %% [markdown]
# Exercice 4 - Créer une cellule markdown pour lister les langages de la science des données
#
# Commencez la cellule par une ligne d’aperçu telle que :
#
# Certains des langages populaires que les scientifiques des données utilisent sont :
# Ensuite, créez une liste ordonnée (c’est-à-dire numérotée) énumérant 3 (ou plus) langages couramment utilisés pour la science des données.

# %% [markdown]
# Certains des langages populaires que les scientifiques des données utilisent sont :
#
# 1. Python
# 2. R
# 3. SQL

# %% [markdown]
# Copyright ©2024 IBM Corporation. All rights reserved.

# %% [markdown]
# Exercice 5 - Créer une cellule markdown pour lister les bibliothèques de la science des données
#
# Ajoutez une ligne d’aperçu à la cellule comme :
#
# Certaines des bibliothèques couramment utilisées par les scientifiques des données incluent :
# En dessous de cette ligne, ajoutez une liste ordonnée énumérant 3 (ou plus) bibliothèques couramment utilisées en science des données.

# %% [markdown]
# Certaines des bibliothèques couramment utilisées par les scientifiques des données incluent :
#
# 1. Pandas
# 2. Numpy
# 3. Seaborn

# %% [markdown]
# Exercice 6 - Créer une cellule markdown avec un tableau des outils de la science des données
#
# Créez un tableau à une seule colonne dans cette cellule avec la première ligne contenant l’en-tête Outils de la science des données. Les trois lignes suivantes dans le tableau devraient indiquer trois outils open source d’environnement de développement utilisés en science des données.

# %% [markdown]
# | Outils de la science des données |
# ------------------------------------
# |       Visual studio code         |
# |            Rstudio               |
# |              Git                 |

# %% [markdown]
# Exercice 7 - Créer une cellule markdown introduisant des exemples d’expressions arithmétiques
#
# Ajoutez une ligne dans cette cellule avec un en-tête de style H3 avec un texte comme :
#
# Voici quelques exemples d'évaluation d'expressions arithmétiques en Python

# %% [markdown]
# ### Voici quelques exemples d'évaluation d'expressions arithmétiques en Python
# 2+2

# %% [markdown]
# Exercice 8 - Créer une cellule de code pour multiplier et additionner des nombres
#
# Dans cette cellule de code, évaluez l’expression (3*4)+5.
# Incluez une ligne de commentaire avant l’expression pour expliquer l’opération par exemple Ceci est une simple expression arithmétique pour multiplier puis additionner des entiers.
# Ensuite, exécutez la cellule pour vous assurer que l’expression renvoie la sortie attendue de 17

# %%
# Ceci est une simple expression arithmétique pour multiplier puis additionner des entiers.
(3*4)+5
# Out:
# 17

# %% [markdown]
# Exercice 9 - Créer une cellule de code pour convertir des minutes en heures
#
# Dans cette cellule de code, écrivez une expression qui convertit 200 minutes en heures.
# Incluez une ligne de commentaire avant l’expression pour expliquer l’opération par exemple Cela convertira 200 minutes en heures en divisant par 60.
# Exécutez la cellule pour évaluer l’expression.

# %%
# Cela convertira 200 minutes en heures en divisant par 60.
200/60
# Out:
# 3.3333333333333335

# %% [markdown]
# Exercice 11 - Créer une cellule markdown pour indiquer le nom de l’Auteur
#
# Dans cette cellule markdown, incluez le texte suivant Auteur en en-tête de style H2. Incluez votre nom en texte régulier sous le mot Auteur.

# %% [markdown]
# ## Auteur
# Aliou THIELO
